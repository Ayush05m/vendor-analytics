# %% [markdown]
# ## Exploratory Data Analysis
# Understanding the dataset to explore how the data is present in the database and if there is a need of creating some aggregated tables that can help with:
#
# • Vendor selection for profitability
#
# • Product Pricing Optimization

# %%
import pandas as pd
import sqlite3

# %%
# creating database connection
conn = sqlite3. connect( 'inventory.db')
# checking tables present in the database
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'" , conn)
tables
# Out:
#               name
# 0            sales
# 1   vendor_invoice
# 2  begin_inventory
# 3    end_inventory
# 4  purchase_prices
# 5        purchases

# %%
pd.read_sql("select count(*) from purchases", conn)
# Out:
#    count(*)
# 0   2372474

# %%
for table in tables ['name']:
    print( '—'*50, f'{table}' , '-'*50)
    print( 'Count of records:', pd.read_sql(f"select count(*) as count from {table}", conn)['count'].values[0])
    display(pd.read_sql(f"select * from {table} limit 5", conn))
# Out:
# —————————————————————————————————————————————————— sales --------------------------------------------------
# Count of records: 12825363
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         16.49       16.49  2024-01-01   750.0
# 1              2         32.98       16.49  2024-01-02   750.0
# 2              1         16.49       16.49  2024-01-03   750.0
# 3              1         14.49       14.49  2024-01-08   750.0
# ...

# %%
purchases = pd.read_sql_query("select * from purchases where VendorNumber = 4466", conn)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
sales = pd.read_sql("SELECT * FROM sales", conn, parse_dates=['SalesDate'])
sales['month'] = sales['SalesDate'].dt.to_period('M')
sales_monthly = sales.groupby('month').agg(
    total_units_sold=('SalesQuantity', 'sum'),
    total_sales_value=('SalesDollars', 'sum')
).reset_index()
display(sales_monthly)
# Out:
#       month  total_units_sold  total_sales_value
# 0   2024-01           2194959        29854027.92
# 1   2024-02           2125292        28876607.23
# 2   2024-03           2219626        28988411.94
# 3   2024-04           2289425        30723734.63
# 4   2024-05           2624496        36041210.52
# 5   2024-06           2858944        39290701.46
# 6   2024-07           3439648        49696466.85
# 7   2024-08           2892266        39056166.03
# 8   2024-09           2840043        38477538.83
# 9   2024-10           2724657        36433141.73
# 10  2024-11           2950515        42312696.86
# 11  2024-12           3758005        52312248.02

# %%
top_vendors = pd.read_sql("""
SELECT 
    VendorName,
    SUM(SalesDollars) AS total_sales_value
FROM sales
GROUP BY VendorName
ORDER BY total_sales_value DESC
LIMIT 10
""", conn)
display(top_vendors)
# Out:
#                     VendorName  total_sales_value
# 0  DIAGEO NORTH AMERICA INC           68742416.99
# 1        MARTIGNETTI COMPANIES        40992395.93
# 2  PERNOD RICARD USA                  32281247.95
# 3  JIM BEAM BRANDS COMPANY            31906320.54
# 4  BACARDI USA INC                    25014556.89
# 5  CONSTELLATION BRANDS INC           24469172.93
# 6  E & J GALLO WINERY                 18556085.61
# 7  BROWN-FORMAN CORP                  18478557.47
# 8  ULTRA BEVERAGE COMPANY LLP         17822938.45
# 9  M S WALKER INC                     15465247.75

# %%
top_profit = pd.read_sql("""
SELECT 
    s.Brand,
    s.Description,
    SUM(s.SalesDollars) AS total_sales,
    SUM(s.SalesQuantity * p.PurchasePrice) AS total_cost,
    (SUM(s.SalesDollars) - SUM(s.SalesQuantity * p.PurchasePrice)) AS estimated_profit
FROM sales s
LEFT JOIN purchase_prices p ON s.Brand = p.Brand
GROUP BY s.Brand, s.Description
ORDER BY estimated_profit DESC
LIMIT 10
""", conn)
display(top_profit)
# Out:
#    Brand                   Description  total_sales  total_cost  \
# 0   1233       Jack Daniels No 7 Black   5101919.51  3731627.23
# 1   3545               Ketel One Vodka   4223107.62  2973493.82
# 2   4261        Capt Morgan Spiced Rum   4475972.88  3240662.04
# 3   8068              Absolut 80 Proof   4538120.60  3413433.60
# 4   3405         Tito's Handmade Vodka   4819073.49  3716127.93
# 5   6570  Kendall Jackson Chard Vt RSV   2326007.78  1450391.26
# 6   3858              Grey Goose Vodka   3383912.40  2520852.20
# 7   3489                     Tanqueray   2640491.19  1875671.13
# 8   1376                      Jim Beam   2435393.39  1744023.69
# 9   2663            Dewars White Label   2189368.78  1502013.24
#
#    estimated_profit
# 0        1370292.28
# 1        1249613.80
# 2        1235310.84
# 3        1124687.00
# 4        1102945.56
# 5         875616.52
# 6         863060.20
# 7         764820.06
# 8         691369.70
# 9         687355.54

# %%
avg_payment_delay = pd.read_sql("""
SELECT 
    VendorName,
    AVG(julianday(PayDate) - julianday(InvoiceDate)) AS avg_days_to_pay
FROM vendor_invoice
WHERE PayDate IS NOT NULL
GROUP BY VendorName
ORDER BY avg_days_to_pay DESC
LIMIT 10
""", conn)
display(avg_payment_delay)
# Out:
#                         VendorName  avg_days_to_pay
# 0      AAPER ALCOHOL & CHEMICAL CO        43.000000
# 1      LAUREATE IMPORTS CO                41.000000
# 2                  UNCORKED               39.714286
# 3      GILMANTON WINERY & VINEYARD        39.500000
# 4      VINEDREA WINES LLC                 38.800000
# 5      FLAVOR ESSENCE INC                 38.000000
# 6           MARTIGNETTI COMPANIES         37.888889
# 7  ALISA CARR BEVERAGES                   37.789474
# 8      APPOLO VINEYARDS LLC               37.384615
# 9      R.P.IMPORTS INC                    37.187500

# %%
purchase_prices = pd.read_sql(f"select * from purchase_prices", conn)
purchase_prices.nunique()
# Out:
# Brand             12261
# Description       11114
# Price               380
# Size                 56
# Volume               33
# Classification        2
# PurchasePrice      2314
# VendorNumber        131
# VendorName          136
# dtype: int64

# %%
purchases = pd.read_sql(f"select * from purchases", conn)

# %%
purchases.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
purchases.nunique()
# Out:
# InventoryId       245907
# Store                 80
# Brand              10664
# Description         9652
# Size                  51
# VendorNumber         126
# VendorName           129
# PONumber            5543
# PODate               319
# ReceivingDate        364
# InvoiceDate          373
# PayDate              382
# PurchasePrice       2151
# Quantity             686
# Dollars            33567
# Classification         2
# dtype: int64

# %% [markdown]
# ## Monthly sales (sales table)
# ### Seasonal trend:
# - Slowest months: Jan–Mar (~21–22 lakh units sold, ₹29–30M revenue).
#  - Peak: December — 3.75M units, ₹52M revenue. Likely due to holiday/New Year demand.
# - Mid-year gradual rise: June–July has sharp jump → could be summer/alcohol consumption spike.
#
# ### Business implication:
# - Stock planning should be proactive before July & December.
# - Cash flow can be optimized by preparing inventory before high-demand months.
#
# ### Top vendors by sales
# - DIAGEO NORTH AMERICA INC dominates with ₹68.7M sales (~1.6× bigger than 2nd place).
# - Top 5 vendors together account for over 50% of total sales — business is vendor-concentrated.
# - Risk: Vendor dependency → if DIAGEO faces supply issues, revenue impact will be huge.
#
# ### Profit margins
# - Highest profit brands: Jack Daniels No 7 Black, Ketel One Vodka, Capt Morgan Spiced Rum.
# - Vodka & Whiskey brands dominate profit list → High-demand + decent margin.
# - Jim Beam has lower profit compared to top — could be high sales but lower margin %.
#
# ### Payment delays
# - Some vendors have >40 days average payment time (e.g., AAPER ALCOHOL & CHEMICAL CO at 43 days).
# - This can strain working capital — negotiating shorter payment terms with top vendors can improve liquidity.
# - Martignetti Companies is both top-2 in sales & top-10 in slow payments — high leverage needed.

# %%
inventory_turnover = pd.read_sql("""
SELECT 
    b.Brand,
    b.Description,
    COALESCE(SUM(s.SalesQuantity), 0) AS total_sold,
    COALESCE(b.onHand, 0) AS start_stock,
    COALESCE(e.onHand, 0) AS end_stock,
    ROUND(CAST(SUM(s.SalesQuantity) AS FLOAT) / NULLIF((b.onHand + e.onHand)/2, 0), 2) AS turnover_ratio
FROM begin_inventory b
LEFT JOIN end_inventory e ON b.InventoryId = e.InventoryId
LEFT JOIN sales s ON b.InventoryId = s.InventoryId
GROUP BY b.Brand, b.Description
ORDER BY turnover_ratio DESC
LIMIT 20
""", conn)
display(inventory_turnover)
# Out:
#     Brand                   Description  total_sold  start_stock  end_stock  \
# 0    7715               Andre Extra Dry       45435            0         15
# 1   38370   Oyster Bay Svgn Bl Marlboro       90220            5         24
# 2    9109      Deep Eddy Ruby Red Vodka       32159            3          7
# 3    3452             Vanya Light Vodka       24691            0         11
# 4    2062      Woodford Reserve Bourbon        4862            2          0
# 5    3162         Burnett's Peach Vodka       19162            9          0
# 6    6281      Franzia Sunset Blush Tap       18424            1          7
# 7    3684      Fleischmanns Royal Vodka       51869            0         24
# 8    3253            Gilbeys London Dry       37438            0         18
# 9     811       Jack Daniels No 7 Black       31119            0         16
# 10   5221              RumChata Liqueur       10293            0          6
# ...

# %%
slow_inventory = inventory_turnover[inventory_turnover['turnover_ratio'] < 1].sort_values('turnover_ratio').head(20)
display(slow_inventory)
# Out:
# Empty DataFrame
# Columns: [Brand, Description, total_sold, start_stock, end_stock, turnover_ratio]
# Index: []

# %%
vendor_profit_per_day = pd.read_sql("""
SELECT 
    s.VendorName,
    SUM(s.SalesDollars - (s.SalesQuantity * p.PurchasePrice)) / COUNT(DISTINCT s.SalesDate) AS profit_per_day
FROM sales s
LEFT JOIN purchase_prices p ON s.Brand = p.Brand
GROUP BY s.VendorName
ORDER BY profit_per_day DESC
LIMIT 10
""", conn)
display(vendor_profit_per_day)
# Out:
#                     VendorName  profit_per_day
# 0  DIAGEO NORTH AMERICA INC       51540.652885
# 1        MARTIGNETTI COMPANIES    38566.285879
# 2  CONSTELLATION BRANDS INC       25081.347720
# 3  PERNOD RICARD USA              23930.393297
# 4  JIM BEAM BRANDS COMPANY        23503.476731
# 5  BACARDI USA INC                19584.453626
# 6  E & J GALLO WINERY             18077.747692
# 7  ULTRA BEVERAGE COMPANY LLP     14777.535604
# 8  BROWN-FORMAN CORP              14375.241071
# 9  M S WALKER INC                 13681.161429

# %%
vendor_reliability = pd.read_sql("""
SELECT 
    VendorName,
    AVG(julianday(ReceivingDate) - julianday(PODate)) AS avg_delivery_days
FROM purchases
WHERE ReceivingDate IS NOT NULL AND PODate IS NOT NULL
GROUP BY VendorName
ORDER BY avg_delivery_days 
LIMIT 10
""", conn)
display(vendor_reliability)
# Out:
#                         VendorName  avg_delivery_days
# 0      TRUETT HURST                          5.000000
# 1      HIGHLAND WINE MERCHANTS LLC           5.321429
# 2      LOYAL DOG WINERY                      5.950000
# 3           MARTIGNETTI COMPANIES            6.697279
# 4  ALISA CARR BEVERAGES                      6.809524
# 5      Circa Wines                           6.948498
# 6      PHILLIPS PRODUCTS CO.                 7.012447
# 7      SEA HAGG DISTILLERY LLC               7.022823
# 8      NICHE W & S                           7.069797
# 9      MOONLIGHT MEADERY                     7.083700

# %% [markdown]
# ### Sales Trends
# - Sales revenue peaks in December (holiday effect) with 52M revenue — almost double January.
# - Noticeable jump from May → July (summer sales spike).
# - Consistent demand across the year, but seasonal peaks should guide stocking.
#
# ### Vendor Performance
# - DIAGEO NORTH AMERICA INC is a clear leader in both sales and profit per day — a strategic partner.
# - Martignetti Companies appears both in top sales & profit/day — also worth prioritizing.
# - Some vendors like Bacardi USA contribute well but could be improved by focusing on high-margin products.
#
# ### Product Profitability
# - Jack Daniels, Ketel One, Capt Morgan, Absolut, Tito’s are top in gross profit — these are your "gold" SKUs.
# - High turnover and high margin overlap = invest more in these.
#
# ### Inventory Movement
# - Several products (Andre Extra Dry, Oyster Bay Sauvignon, Deep Eddy Vodka) have extremely high turnover (>6000) — these need constant replenishment to avoid stockouts.
# - The “slow inventory” table is empty in your snippet — either filtering threshold was too strict or data cleanup is needed.
#
# ### Vendor Reliability
# - Vendors like Truett Hurst, Highland Wine Merchants deliver in ~5 days — reliable.
# - Vendors with 7+ days lead time might cause stockouts for high-demand items.

# %% [markdown]
#  # Analysing a particular vendor no. 4466

# %%
purchases = pd.read_sql_query("select * from purchases where VendorNumber = 4466", conn)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases_price = pd.read_sql_query("select * from purchase_prices where VendorNumber = 4466", conn)
purchases_price
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice = pd.read_sql_query("select * from vendor_invoice where VendorNumber = 4466", conn)
vendor_invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
sales = pd.read_sql_query("select * from sales where VendorNo = 4466", conn)
sales
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     9_BLACKPOOL_5215      9   5215  TGI Fridays Long Island Iced  1.75L
# 9449     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9452     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases. groupby( ['Brand', 'PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %% [markdown]
# • The purchases table contains actual purchase data, including the date of purchase, products (brands) purchased by vendors, the amount paid (in dollars), and the quantity purchased.
#
# • The purchase price column is derived from the purchase_prices table, which provides product-wise actual and purchase prices. The combination of vendor and brand is unique in this table.
#
# • The vendor_invoice table aggregates data from the purchases table, summarizing quantity and dollar amounts, along with an additional column for freight. This table maintains uniqueness based on vendor and PO number.
#
# • The sales table captures actual sales transactions, detailing the brands purchased by vendors, the quantity sold, the selling price, and the revenue earned.
#
# As the data that we need for analysis is distributed in different tables, we need to create a summary table containing:
# - purchase transactions made by vendors
# - sales transaction data
# - freight costs for each vendor
# - actual product prices from vendors

# %%
freight_summary = pd. read_sql_query(
    "select VendorNumber, SUM(Freight) as FreightCost From vendor_invoice Group BY VendorNumber", conn)
freight_summary
# Out:
#      VendorNumber  FreightCost
# 0               2        27.08
# 1              54         0.48
# 2              60       367.52
# 3             105        62.39
# 4             200         6.19
# ..            ...          ...
# 121         98450       856.02
# 122         99166       130.09
# 123        172662       178.34
# 124        173357       202.50
# 125        201359         0.09
#
# [126 rows x 2 columns]

# %%
pd.read_sql_query( '''
SELECT
p.VendorNumber,
p.VendorName,
p.Brand,
p.PurchasePrice,
pp.Volume,
pp. Price as ActualPrice,
SUM(p.Quantity) as TotalPurchaseQuantity,
SUM(p.Dollars) as TotalPurchaseDollars
FROM purchases p
JOIN purchase_prices pp
ON p.Brand = pp.Brand
Where p. PurchasePrice > 0
GROUP BY p.VendorNumber, p.VendorName, p.Brand 
ORDER BY TotalPurchaseDollars
''', conn)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
pd.read_sql_query ('''
    SELECT
        VendorNo,
        Brand,
        SUM(SalesDollars) as TotalSalesDollars,
        SUM(SalesPrice) as TotalSalesPrice,
        SUM(SalesQuantity) as TotaliatesQuanity,
        SUM(ExciseTax) as TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
    ORDER BY TotalSalesDollars'''
, conn)
# Out:
#        VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  TotaliatesQuanity  \
# 0          8004   5287               0.98             0.98                  2
# 1          9206   2773               0.99             0.99                  1
# 2          3252   3933               1.98             0.99                  2
# 3          3924   9123               1.98             0.99                  2
# 4         10050   3623               1.98             1.98                  2
# ...         ...    ...                ...              ...                ...
# 11267      3960   3545         4223107.62        545778.28             135838
# 11268      3960   4261         4475972.88        420050.01             200412
# 11269     17035   8068         4538120.60        461140.15             187140
# 11270      4425   3405         4819073.49        561512.37             160247
# 11271      1128   1233         5101919.51        672819.31             142049
#
#        TotalExciseTax
# ...

# %%
import time

start = time.time()

query = """
WITH FreightSummary AS ( 
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),

PurchaseSummary AS (
    SELECT
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price AS ActualPrice,
        pp.Volume,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Dollars) AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    -- Removed the incomplete WHERE clause
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
),

SalesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
)

SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNo
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC;
"""

vendor_sales_summary = pd.read_sql_query(query, conn)

print("Query execution time:", time.time() - start, "seconds")
vendor_sales_summary.head()
# Out:
# Query execution time: 20.948370456695557 seconds
#    VendorNumber                   VendorName  Brand              Description  \
# 0          1128  BROWN-FORMAN CORP             1233  Jack Daniels No 7 Black
# 1          4425        MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035  PERNOD RICARD USA             8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC      4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC      3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99   1750                 145080
# 1          23.19        28.99   1750                 164038
# 2          18.24        24.99   1750                 187407
# 3          16.17        22.99   1750                 201682
# 4          21.89        29.99   1750                 138109
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesDollars  \
# ...

# %% [markdown]
# This query generates a vendor-wise sales and purchase summary, which is valuable for:
#
# ##### Performance Optimization:
#
# - The query involves heavy joins and aggregations on large datasets like sales and purchases.
# - Storing the pre-aggregated results avpids repeated expensive computations.
# - Helps in analyzing sales, purchases, and pricing for different vendors and brands.
# - Future Benefits of Storing this data for faster Dashboarding & Reporting.
# - Instead of running expensive queries each time, dashboards can fetch data quickly from vendor_sales_summary.

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesQuantity       178
# TotalSalesDollars        178
# TotalSalesPrice          178
# TotalExciseTax           178
# FreightCost                0
# dtype: int64

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                    object
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary['Volume'] = vendor_sales_summary['Volume'].astype('float64')
vendor_sales_summary.fillna(0, inplace = True)

# %%
vendor_sales_summary['VendorName'] = vendor_sales_summary['VendorName'].str.strip()

# %%
vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesDollars'] - vendor_sales_summary['TotalPurchaseDollars']
vendor_sales_summary['ProfitMargin vendor'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesDollars'])*100

# %%
vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity'] / vendor_sales_summary['TotalPurchaseQuantity']

# %%
vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesDollars'] - vendor_sales_summary['TotalPurchaseDollars']

# %%
cursor = conn.cursor()

# %%
cursor. execute( """
CREATE TABLE vendor_sales_summary (
    VendorNumber INT,
    VendorName VARCHAR(100),
    Brand INT,
    Description VARCHAR(100) ,
    PurchasePrice DECIMAL (10, 2),
    ActualPrice ,
    Volume,
    TotalPurchaseQuantity INT,
    TotalPurchaseDollars DECIMAL (15, 2),
    TotalSalesQuantity INT,
    TotalSalesDollars DECIMAL (15, 2),
    TotalSalesPrice DECIMAL (15, 2),
    TotalExciseTax DECIMAL (15,2),
    FreightCost DECIMAL (15, 2),
    GrossProfit DECIMAL (15, 2),
    ProfitMargin DECIMAL (15, 2),
    StockTurnover DECIMAL (15, 2) ,
    SatesToPurchaseRatio DECIMAL (15, 2),
    PRIMARY KEY (VendorNumber, Brand)
);
""")

# %%
# cursor.execute( """
# DROP TABLE vendor_sales_summary; """)

# %%
# Convert all columns to plain Python types
# vendor_sales_summary2 = vendor_sales_summary.apply(
#     lambda x: x if isinstance(x, (int, float, str, type(None))) else str(x)
# )

vendor_sales_summary.to_sql('vendor_sales_summary', conn, if_exists='replace', index=False)
# Out:
# 10693

# %%
# conn.execute("DROP TABLE IF EXISTS vendor_sales_summary;")
# conn.commit()

# %%
pd.read_sql_query ('select * from vendor_sales_summary', conn)
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
# 10692          2561        EDRINGTON AMERICAS   2166
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...
